# %% [markdown]
# <a href="https://colab.research.google.com/github/amanupg/Imageclef-2024/blob/main/Inception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
import pandas as pd
import pathlib
from sklearn.cluster import KMeans
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPooling2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_model = InceptionV3(weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
input_shape = (256, 256, 1)  # Grayscale images
input_layer = tf.keras.layers.Input(shape=input_shape)
gray_convert = tf.keras.layers.Lambda(lambda x: tf.image.grayscale_to_rgb(x))(input_layer)

# Pass through InceptionV3 base model
x = base_model(gray_convert)

# Add custom classification head
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(3, activation='softmax')(x)

# %%
model = Model(inputs=input_layer, outputs=predictions)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
train_ds = keras.utils.image_dataset_from_directory(
    directory='/content/drive/MyDrive/Machine_Learning/Research/Train',
    labels='inferred',
    label_mode='int',
    batch_size=16,
    image_size=(256, 256),
    color_mode='grayscale'
)
validation_ds = keras.utils.image_dataset_from_directory(
    directory='/content/drive/MyDrive/Machine_Learning/Research/Test',
    labels='inferred',
    label_mode='int',
    batch_size=16,
    image_size=(256, 256),
    color_mode='grayscale'
)
# Out:
# Found 540 files belonging to 3 classes.
# Found 60 files belonging to 3 classes.

# %%
def process(image, label):
    image = tf.cast(image / 255, tf.float32)
    label = tf.one_hot(label, depth=3)  # One-hot encode labels for 3 classes
    return image, label


train_ds = train_ds.map(process)
validation_ds = validation_ds.map(process)

# %%
model_path = "/content/drive/MyDrive/Machine_Learning/Research/Model/vgg.h5"
csv_path = "/content/drive/MyDrive/Machine_Learning/Research/Model/vgg.log"
callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        CSVLogger(csv_path),
        TensorBoard(),
        EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=False),
    ]

model.fit(
    train_ds,
    epochs=200,
    validation_data=validation_ds,
    callbacks=callbacks,
    shuffle=False
)
# Out:
# Epoch 1/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.9241
# Epoch 1: val_loss improved from inf to 1332.63562, saving model to /content/drive/MyDrive/Machine_Learning/Research/Model/vgg.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 34/34 [==============================] - 55s 419ms/step - loss: 0.2384 - accuracy: 0.9241 - val_loss: 1332.6356 - val_accuracy: 0.3333
# Epoch 2/200
# 34/34 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9963
# Epoch 2: val_loss improved from 1332.63562 to 238.11111, saving model to /content/drive/MyDrive/Machine_Learning/Research/Model/vgg.h5
# 34/34 [==============================] - 4s 101ms/step - loss: 0.0058 - accuracy: 0.9963 - val_loss: 238.1111 - val_accuracy: 0.3333
# Epoch 3/200
# 34/34 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9981
# Epoch 3: val_loss did not improve from 238.11111
# 34/34 [==============================] - 3s 62ms/step - loss: 0.0063 - accuracy: 0.9981 - val_loss: 324.7315 - val_accuracy: 0.3333
# Epoch 4/200
# 34/34 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9963
# Epoch 4: val_loss improved from 238.11111 to 6.93351, saving model to /content/drive/MyDrive/Machine_Learning/Research/Model/vgg.h5
# 34/34 [==============================] - 4s 102ms/step - loss: 0.0252 - accuracy: 0.9963 - val_loss: 6.9335 - val_accuracy: 0.5667
# Epoch 5/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.2270 - accuracy: 0.9602
# Epoch 5: val_loss did not improve from 6.93351
# 34/34 [==============================] - 3s 58ms/step - loss: 0.2342 - accuracy: 0.9556 - val_loss: 3216.9561 - val_accuracy: 0.3333
# Epoch 6/200
# 34/34 [==============================] - ETA: 0s - loss: 0.2150 - accuracy: 0.9648
# Epoch 6: val_loss did not improve from 6.93351
# 34/34 [==============================] - 2s 59ms/step - loss: 0.2150 - accuracy: 0.9648 - val_loss: 1456.8809 - val_accuracy: 0.3333
# Epoch 7/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.2359 - accuracy: 0.9545
# Epoch 7: val_loss did not improve from 6.93351
# 34/34 [==============================] - 2s 59ms/step - loss: 0.2307 - accuracy: 0.9556 - val_loss: 24478.5000 - val_accuracy: 0.3333
# Epoch 8/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9886
# Epoch 8: val_loss did not improve from 6.93351
# 34/34 [==============================] - 2s 64ms/step - loss: 0.0305 - accuracy: 0.9889 - val_loss: 445.4744 - val_accuracy: 0.3667
# Epoch 9/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.1341 - accuracy: 0.9659
# Epoch 9: val_loss did not improve from 6.93351
# 34/34 [==============================] - 2s 61ms/step - loss: 0.1486 - accuracy: 0.9611 - val_loss: 460.3976 - val_accuracy: 0.3333
# Epoch 10/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.0197 - accuracy: 0.9962
# Epoch 10: val_loss did not improve from 6.93351
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0192 - accuracy: 0.9963 - val_loss: 18.4985 - val_accuracy: 0.6833
# Epoch 11/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 11: val_loss improved from 6.93351 to 3.44702, saving model to /content/drive/MyDrive/Machine_Learning/Research/Model/vgg.h5
# 34/34 [==============================] - 6s 161ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.4470 - val_accuracy: 0.7667
# Epoch 12/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 12: val_loss improved from 3.44702 to 2.20299, saving model to /content/drive/MyDrive/Machine_Learning/Research/Model/vgg.h5
# 34/34 [==============================] - 4s 103ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.2030 - val_accuracy: 0.7500
# Epoch 13/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9981
# Epoch 13: val_loss improved from 2.20299 to 0.00021, saving model to /content/drive/MyDrive/Machine_Learning/Research/Model/vgg.h5
# 34/34 [==============================] - 5s 103ms/step - loss: 0.0029 - accuracy: 0.9981 - val_loss: 2.0956e-04 - val_accuracy: 1.0000
# Epoch 14/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.1593 - accuracy: 0.9792
# Epoch 14: val_loss did not improve from 0.00021
# 34/34 [==============================] - 3s 58ms/step - loss: 0.1587 - accuracy: 0.9796 - val_loss: 4.2314 - val_accuracy: 0.3833
# Epoch 15/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9981
# Epoch 15: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0098 - accuracy: 0.9963 - val_loss: 14.7001 - val_accuracy: 0.3333
# Epoch 16/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 0.9924
# Epoch 16: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 56ms/step - loss: 0.0229 - accuracy: 0.9926 - val_loss: 3.1991 - val_accuracy: 0.6667
# Epoch 17/200
# 34/34 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 17: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 58ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0333 - val_accuracy: 0.9833
# Epoch 18/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9962
# Epoch 18: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 66ms/step - loss: 0.0186 - accuracy: 0.9963 - val_loss: 4.0187e-04 - val_accuracy: 1.0000
# Epoch 19/200
# 34/34 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9981
# Epoch 19: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0026 - accuracy: 0.9981 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 20/200
# 33/34 [============================>.] - ETA: 0s - loss: 3.6108e-04 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 60ms/step - loss: 3.5498e-04 - accuracy: 1.0000 - val_loss: 3.2310e-04 - val_accuracy: 1.0000
# Epoch 21/200
# 34/34 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9981
# Epoch 21: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 58ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 2.3802e-04 - val_accuracy: 1.0000
# Epoch 22/200
# 34/34 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9963
# Epoch 22: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 58ms/step - loss: 0.0171 - accuracy: 0.9963 - val_loss: 20.0604 - val_accuracy: 0.3500
# Epoch 23/200
# 34/34 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9926
# Epoch 23: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0305 - accuracy: 0.9926 - val_loss: 4.0938 - val_accuracy: 0.6000
# Epoch 24/200
# 34/34 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.9741
# Epoch 24: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0945 - accuracy: 0.9741 - val_loss: 6.5872 - val_accuracy: 0.6333
# Epoch 25/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 57ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 17.1811 - val_accuracy: 0.5667
# Epoch 26/200
# 34/34 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.7875 - val_accuracy: 0.7500
# Epoch 27/200
# 33/34 [============================>.] - ETA: 0s - loss: 4.8887e-04 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 59ms/step - loss: 4.7888e-04 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.9333
# Epoch 28/200
# 34/34 [==============================] - ETA: 0s - loss: 0.1440 - accuracy: 0.9759
# Epoch 28: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 60ms/step - loss: 0.1440 - accuracy: 0.9759 - val_loss: 116.9376 - val_accuracy: 0.3333
# Epoch 29/200
# 33/34 [============================>.] - ETA: 0s - loss: 0.1444 - accuracy: 0.9716
# Epoch 29: val_loss did not improve from 0.00021
# 34/34 [==============================] - 2s 59ms/step - loss: 0.1424 - accuracy: 0.9722 - val_loss: 1387.1361 - val_accuracy: 0.3333
# Epoch 30/200
# 34/34 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.
# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/Machine_Learning/Research/Model/vgg.h5')

# %%
# Remove the last layer of the model
feature_extractor = Model(inputs=model.input, outputs=model.layers[-2].output)

# Extract features from the test dataset
test_features = feature_extractor.predict(validation_ds)

num_clusters = 4  # specify the number of clusters
kmeans = KMeans(n_clusters=num_clusters)
clusters = kmeans.fit_predict(test_features)

# clusters variable now contains the cluster labels for each image in the test dataset

kmeans.labels_
# Out:
# 4/4 [==============================] - 1s 11ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([2, 1, 1, 3, 2, 1, 0, 0, 2, 2, 1, 0, 2, 2, 2, 1, 0, 3, 0, 0, 3, 2,
#        1, 2, 0, 2, 0, 0, 3, 3, 0, 2, 0, 1, 0, 3, 1, 0, 1, 1, 2, 0, 2, 1,
#        0, 2, 2, 2, 1, 2, 1, 0, 0, 2, 2, 2, 0, 0, 1, 0], dtype=int32)

# %%
data_dir = '/content/drive/MyDrive/Machine_Learning/Research/ImageCLEFmedical  GANs 2024 - Task2 test/generated_images'
data_dir = pathlib.Path(data_dir)

# %%
image_count = len(list(data_dir.glob('*.*')))

# Create a dataset of image file paths
list_ds = tf.data.Dataset.list_files(str(data_dir/'*'), shuffle=False)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
def process_path(file_path):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_png(img, channels=1)  # Use decode_png if images are png format
    img = tf.image.resize(img, [256, 256])
    img = tf.expand_dims(img, axis=-1)  # Add a channel dimension
    img = (img / 255.0)  # Normalize pixels to 0,1
    return img

# %%
new_dataset = list_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)

# %%
# Remove the last layer of the model
feature_extractor = Model(inputs=model.input, outputs=model.layers[-2].output)

# Batch the dataset
new_dataset = new_dataset.batch(16)  # Replace 16 with your desired batch size

# Extract features from the new dataset
new_features = feature_extractor.predict(new_dataset)

# Perform clustering on the extracted features
num_clusters = 4  # specify the number of clusters
kmeans = KMeans(n_clusters=num_clusters)
new_clusters = kmeans.fit_predict(new_features)

# new_clusters variable now contains the cluster labels for each image in the new dataset
print(kmeans.labels_)
# Out:
# 190/190 [==============================] - 53s 271ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [1 1 3 ... 3 0 0]

# %%
print(kmeans.labels_[:20])
# Out:
# [1 1 3 1 1 2 3 3 0 0 1 3 0 2 0 1 3 1 3 1]

# %%
# Load the provided run.csv file
provided_run_path = '/content/drive/MyDrive/Machine_Learning/Research/ImageCLEFmedical  GANs 2024 - Task2 test/Inception.csv'

# Read the file without header
provided_run_df = pd.read_csv(provided_run_path, header=None, names=['data'])

# Map figure IDs to cluster labels
figure_ids = provided_run_df['data'].str.split('\t', expand=True)[0]  # Extract figure IDs
cluster_mapping = dict(zip(figure_ids, new_clusters + 1))  # Adding 1 to clusters to match the required labels [1, 2, 3, 4]

# Create a DataFrame with image IDs and corresponding cluster mappings
result_df = pd.DataFrame({'ImageID': figure_ids, 'Cluster': [cluster_mapping[x] for x in figure_ids]})

# Save the DataFrame to the same CSV file (overwrite the existing file)
result_df.to_csv(provided_run_path, index=False, header=False)
